# %%
import requests
import time
import pandas as pd

url = "https://api.coingecko.com/api/v3"

endpoints = [
     "/simple/supported_vs_currencies"
    ,"/coins/list"
    ,"/coins/categories/list"
    ,"/coins/categories"
]

headers = {"x-cg-demo-api-key": "CG-x2tP7aTTn1Q3PvChKFvp7fiR"}

json_data = {}
    
for endpoint in endpoints:
    print(f"Processando o endpoint:{endpoint}")

    print(url+endpoint)

    response = requests.get(url+endpoint, headers=headers)

    if response.status_code != 200:
        print(f"Erro no endpoint {endpoint}:{response.status_code}")
        continue 
    
    data = response.json()

    print(f"Execução bem sucedida no endpoint: {endpoint}") 

    time.sleep(30)

# %%
print(json_data)
